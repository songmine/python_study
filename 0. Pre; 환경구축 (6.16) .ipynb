# %%
import pandas as pd

# %%
import pandas as pd    #shift Ctrl -

# %% [markdown]
# # 이것은 설명문입니다.

# %% [markdown]
# ## 이것은 설명문입니다.

# %% [markdown]
# ### 이것은 설명문입니다.

# %% [markdown]
# #### 이것은 설명문입니다.

# %% [markdown]
# ##### 이것은 설명문입니다.

# %% [markdown]
# > 제목1
# >> 제목2
# >>> 제목3

# %% [markdown]
# ---

# %% [markdown]
# <hr>

# %% [markdown]
# 가나다라<br>마바사아

# %% [markdown]
# ![Alt text](a.jpg)

# %% [markdown]
# ![Alt text](./이미지/b.jpg)

# %%
from IPython.display import Image

# %%
Image("./이미지/b.jpg")

# %%
Image("a.jpg")

# %%
<img src="./이미지/b.jpg">      #오류~~~~~
# Out:
#   File "<ipython-input-2-64e31a2b3f0d>", line 1
#     <img src="./이미지/b.jpg">      #오류~~~~~
#     ^
# SyntaxError: invalid syntax
